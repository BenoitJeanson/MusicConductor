# %%
from tabGen import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-4f8650219f8a> in <module>
# ----> 1 from tabGen import *
#
# ModuleNotFoundError: No module named 'tabGen'

# %%
sys.path
# Out:
# ['c:\\Users\\jeansonben\\.vscode\\extensions\\ms-toolsai.jupyter-2021.8.1054968649\\pythonFiles\\vscode_datascience_helpers',
#  'c:\\Users\\jeansonben\\.vscode\\extensions\\ms-toolsai.jupyter-2021.8.1054968649\\pythonFiles',
#  'c:\\Users\\jeansonben\\.vscode\\extensions\\ms-toolsai.jupyter-2021.8.1054968649\\pythonFiles\\lib\\python',
#  'C:\\Users\\jeansonben\\AppData\\Local\\Programs\\Python\\Python37\\python37.zip',
#  'C:\\Users\\jeansonben\\AppData\\Local\\Programs\\Python\\Python37\\DLLs',
#  'C:\\Users\\jeansonben\\AppData\\Local\\Programs\\Python\\Python37\\lib',
#  'C:\\Users\\jeansonben\\AppData\\Local\\Programs\\Python\\Python37',
#  '',
#  'C:\\Users\\jeansonben\\AppData\\Local\\Programs\\Python\\Python37\\lib\\site-packages',
#  'C:\\Users\\jeansonben\\AppData\\Local\\Programs\\Python\\Python37\\lib\\site-packages\\win32',
#  'C:\\Users\\jeansonben\\AppData\\Local\\Programs\\Python\\Python37\\lib\\site-packages\\win32\\lib',
# ...
